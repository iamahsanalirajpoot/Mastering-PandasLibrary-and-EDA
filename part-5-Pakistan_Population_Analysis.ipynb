# %% [markdown]
# # **Pakistan Population Analysis**

# %% [markdown]
# Author Name : Ahsan Ali Rajpoot
# - Linkedin : [linkedin.com/in/iamahsanalirajpoot](linkedin.com/in/iamahsanalirajpoot)
# - Facebook : [facebook.com/iamahsanalirajpoot](facebook.com/iamahsanalirajpoot)
# - GitHub : [github.com/iamahsanalirajpoot](github.com/iamahsanalirajpoot)
# - Kaggle : [kaggle.com/ahsanalirajpoot](kaggle.com/ahsanalirajpoot)

# %% [markdown]
# The Data was collected from the [www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-datasetset](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset)\
#  \
# **Years of Data:**
# 1. 2027
# 2. 1998

# %% [markdown]
# ## ***The Dataset collected from the source has following description***
# ### **About Dataset**
# **Description:**</br></br>
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# **Features:**</br></br>
# `Province:` The administrative provinces or regions of Pakistan where the census data was collected.
#
# `Division:` The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# `District:` Districts within each division, representing larger administrative units.
#
# `Sub-Division:` Sub-divisions or tehsils within each district, providing more localized data.
#
# `Area:` The land area (in square kilometers) of each sub-division.
#
# `Urban Population 2017:` The population of urban areas within each sub-division for the year 2017.
#
# `Rural Population 2017:` The population of rural areas within each sub-division for the year 2017.
#
# `Male Population 2017:` The male population within each sub-division for the year 2017.
#
# `Female Population 2017:` The female population within each sub-division for the year 2017.
#
# `Transgender Population 2017:` The population of transgender individuals within each sub-division for the year 2017.
#
# `Sex Ratio 2017:` The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# `Population in 1998:` The total population of each sub-division as recorded in the 1998 census.
#
# `Annual Growth Rate:` The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# **Data Source:** </br> </br>
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# **Data Usage:** </br></br>
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## **Purpose of this analysis:**
#
# The Purpose of this analysis is to find out the answer of the list of following questions:
#
# 1. How many provinces are there in Pakistan?
# 2. How many divisions exist within Pakistan?
# 3. What is the total number of districts in Pakistan?
# 4. How many sub-divisions are there in Pakistan?
# 5. What is the number of administrative units (e.g., divisions, districts, sub-divisions) in each province?
# 6. Which province covers the largest area in Pakistan?
# 7. Which province has the smallest area?
# 8. What is the total population of Pakistan (including both rural and urban areas)?
# 9. What is the average population of each division?
# 10. Which province division has the largest population?
# 11. What is the total population of each province?
# 12. What is the gender distribution (male/female) in each province?
# 13. In which province is the rural population of all genders the highest?
# 14. What is the urban vs. rural population in each province?
# 15. What is the overall sex ratio in each province?
# 16. How does the sex ratio differ in urban and rural areas?
# 17. What is the average household size in each province (both by Rural and Urban)?
# 18. How does the average household size differ between rural and urban areas?
# 19. What was the population of each province in the 1998 census?
# 20. What is the growth rate of the population in each province from 1998 to 2017?

# %% [markdown]
# **NOTE:** In most cases, I will not consider the Transgender Population in my analyasis!

# %% [markdown]
# **importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **importing the dataset**

# %%
# importing the dataset
df = pd.read_csv('../data/population_of_pakistan.csv')

# %% [markdown]
# ## **Basic Data Exploration and Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None) # -> enabling max column priniting
pd.set_option('display.max_rows', None) # -> enabling max row printing

# %%
# vieawing the first 5 rows
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# viewing the last 5 rows
df.tail()
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 523   SARAROGHA TEHSIL         813.0              98180         51479
# 524    SERWEKAI TEHSIL         398.0              54540         28695
# 525      TIARZA TEHSIL         734.0              45156         23649
# 526  TOI KHULLA TEHSIL         567.0              50413         27462
# 527        WANA TEHSIL        2315.0             153156         81342
#
#      FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# 523           46694                    7             110.25
# ...

# %%
# lets see all columns names at once
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# lets have a look on dtypes
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
# summary statistic
statistic_summary = df.describe()
statistic_summary
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
# Taking transpose of the summary statistics because it is easier to read
statistic_summary.T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
# Corss checking the missing values
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %% [markdown]
# A heatmap for missing values demonstrates that there are no missing numbers

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **Question 1.** How many provinces are there in Pakistan?

# %%
# name of all provinces
df['PROVINCE'].unique()
# Out:
# array(['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK', 'KPK/FATA'], dtype=object)

# %%
# number of provinces
df['PROVINCE'].nunique()
# Out:
# 5

# %% [markdown]
# ***Answer:** There are 5 provinces in Pakistan.*

# %% [markdown]
# **Question 2.** How many divisions exist within Pakistan?

# %%
# name of all divisions
df['DIVISION'].unique()
# Out:
# array(['BAHAWALPUR DIVISION', 'D.G.KHAN DIVISION', 'FAISALABAD DIVISION',
#        'GUJRANWALA DIVISION', 'LAHORE DIVISION', 'MULTAN DIVISION',
#        'RAWALPINDI DIVISION', 'SAHIWAL DIVISION', 'SARGODHA DIVISION',
#        'Badin Division', 'Hyderabad Division', 'Karachi Division',
#        'Larkana Division', 'Mirpurkhas Division',
#        'Shaheed Benazirabad Division', 'Sukkur Division',
#        'Makran Division', 'Kalat Division', 'Naseerabad Division',
#        'Quetta Division', 'Zhob Division', 'BANNU DIVISION',
#        'DERA ISMAIL KHAN DIVISION', 'HAZARA DIVISION', 'KOHAT DIVISION',
#        'MARDAN DIVISION', 'PESHAWAR DIVISION', 'MALAKAND DIVISION'],
#       dtype=object)

# %%
# total number of divisions
df['DIVISION'].nunique()
# Out:
# 28

# %% [markdown]
# ***Answer:** There are 28 divisions in Pakistan.*

# %% [markdown]
# **Question 3.** What is the total number of districts in Pakistan?

# %%
# Name of all districts
df['DISTRICT'].unique()
# Out:
# array(['BAHAWALNAGAR DISTRICT', 'BAHAWALPUR DISTRICT',
#        'RAHIM YAR KHAN DISTRICT', 'DERA GHAZI KHAN DISTRICT',
#        'LAYYAH DISTRICT', 'MUZAFFARGARH DISTRICT', 'RAJANPUR DISTRICT',
#        'CHINIOT DISTRICT', 'FAISALABAD DISTRICT', 'JHANG DISTRICT',
#        'TOBA TEK SINGH DISTRICT', 'GUJRANWALA DISTRICT',
#        'GUJRAT DISTRICT', 'HAFIZABAD DISTRICT',
#        'MANDI BAHAUDDIN DISTRICT', 'NAROWAL DISTRICT', 'SIALKOT DISTRICT',
#        'KASUR DISTRICT', 'LAHORE DISTRICT', 'NANKANA SAHIB DISTRICT',
#        'SHEIKHUPURA DISTRICT', 'KHANEWAL DISTRICT', 'LODHRAN DISTRICT',
#        'MULTAN DISTRICT', 'VEHARI DISTRICT', 'ATTOCK DISTRICT',
#        'CHAKWAL DISTRICT', 'JHELUM DISTRICT', 'RAWALPINDI DISTRICT',
#        'OKARA DISTRICT', 'PAKPATTAN DISTRICT', 'SAHIWAL DISTRICT',
#        'BHAKKAR DISTRICT', 'KHUSHAB DISTRICT', 'MIANWALI DISTRICT',
#        'SARGODHA DISTRICT', 'BADIN DISTRICT', 'DADU DISTRICT',
# ...

# %%
# total number of districts
df['DISTRICT'].nunique()
# Out:
# 131

# %% [markdown]
# ***Answer:** There are 131 districts in Pakistan.*

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Quesion 4.** How many sub-divisions are there in Pakistan?

# %%
# number of sub-divisions in pakistan
df['SUB DIVISION'].nunique()
# Out:
# 528

# %% [markdown]
# ***Answer:** There are 528 sub-divisions in Pakistan.*

# %% [markdown]
# **Question 5.** What is the number of administrative units (e.g., divisions, districts, sub-divisions) in each province?

# %%
df.groupby(['PROVINCE', 'DIVISION']).first()
# Out:
#                                                            DISTRICT  \
# PROVINCE    DIVISION
# BALOCHISTAN Kalat Division                           KALAT DISTRICT
#             Makran Division                         AWARAN DISTRICT
#             Naseerabad Division                 JAFFARABAD DISTRICT
#             Quetta Division                         CHAGAI DISTRICT
#             Zhob Division                          BARKHAN DISTRICT
# KPK         BANNU DIVISION                           BANNU DISTRICT
#             DERA ISMAIL KHAN DIVISION     DERA ISMAIL KHAN DISTRICT
#             HAZARA DIVISION                     ABBOTTABAD DISTRICT
#             KOHAT DIVISION                           HANGU DISTRICT
#             MALAKAND DIVISION                        BUNER DISTRICT
#             MARDAN DIVISION                         MARDAN DISTRICT
#             PESHAWAR DIVISION                    CHARSADDA DISTRICT
# ...

# %% [markdown]
# Number of divisions in each province

# %%
# Number of divisions in each province
divisions_per_province = df.groupby('PROVINCE')['DIVISION'].nunique()
print("Divisions per province:\n", divisions_per_province)
# Out:
# Divisions per province:
#  PROVINCE
# BALOCHISTAN    5
# KPK            7
# KPK/FATA       5
# PUNJAB         9
# SINDH          7
# Name: DIVISION, dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=divisions_per_province.index, y=divisions_per_province.values, palette='Blues')
plt.title('Number of Divisions in Each Province')
plt.xlabel('Province')
plt.ylabel('Number of Divisions')
plt.tight_layout()
plt.show()

# %% [markdown]
# Number of districts in each province

# %%
# Number of districts in each province
districts_per_province = df.groupby('PROVINCE')['DISTRICT'].nunique()
print("Districts per province:\n", districts_per_province)
# Out:
# Districts per province:
#  PROVINCE
# BALOCHISTAN    31
# KPK            23
# KPK/FATA       12
# PUNJAB         36
# SINDH          29
# Name: DISTRICT, dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=districts_per_province.index, y=districts_per_province.values, palette='Greens')
plt.title('Number of Districts in Each Province')
plt.xlabel('Province')
plt.ylabel('Number of Districts')
plt.tight_layout()
plt.show()

# %% [markdown]
# Number of sub-divisions in each province

# %%
# Number of sub-divisions in each province
subdivisions_per_province = df.groupby('PROVINCE')['SUB DIVISION'].nunique()
print("Sub-divisions per province:\n", subdivisions_per_province)
# Out:
# Sub-divisions per province:
#  PROVINCE
# BALOCHISTAN    131
# KPK             71
# KPK/FATA        46
# PUNJAB         143
# SINDH          137
# Name: SUB DIVISION, dtype: int64

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x=subdivisions_per_province.index, y=subdivisions_per_province.values, palette='Oranges')
plt.title('Number of Sub-divisions in Each Province')
plt.ylabel('Number of Sub-divisions')
plt.show()

# %% [markdown]
# ***Answer:** The number of administrative units in each province is as follows:*<br/><br/>
# ***PUNJAB:*** 9 Divisions, 36 Districts, 143 Sub-Divisions<br/>
# ***SINDH:*** 7 Divisions, 29 Districts, 137 Sub-Divisions<br/>
# ***KPK:*** 7 Divisions, 23 Districts, 71 Sub-Divisions<br/>
# ***BALOCHISTAN:*** 5 Divisions, 31 Districts, 131 Sub-Divisions<br/>
# ***KPK/FATA:*** 5 Divisions, 12 District, 46 Sub-Divisions

# %%
admin_units = pd.DataFrame({
    'Divisions': divisions_per_province,
    'Districts': districts_per_province,
    'Sub-Divisions': subdivisions_per_province
})

admin_units
# Out:
#              Divisions  Districts  Sub-Divisions
# PROVINCE
# BALOCHISTAN          5         31            131
# KPK                  7         23             71
# KPK/FATA             5         12             46
# PUNJAB               9         36            143
# SINDH                7         29            137

# %%
admin_units.plot(kind='bar', figsize=(10, 6), color=['blue', 'green', 'orange'])
plt.xlabel('Province')
plt.ylabel('Count')
plt.title('Administrative Units in Each Province')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Question 6.** Which province covers the largest area in Pakistan?

# %%
# area of each province
area_per_province = df.groupby('PROVINCE')['AREA (sq.km)'].sum().sort_values(ascending=False)

area_per_province
# Out:
# PROVINCE
# BALOCHISTAN    345464.0
# PUNJAB         202693.0
# SINDH          140136.0
# KPK             74957.1
# KPK/FATA        24529.0
# Name: AREA (sq.km), dtype: float64

# %%
# barplot for total area by provience 
plt.figure(figsize=(8, 5))
sns.barplot(x=area_per_province.values, y=area_per_province.index, palette='Blues_r')
plt.xlabel('Total Area (sq.km)')
plt.ylabel('Province')
plt.title('Total Area by Province')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Answer:* **Balochistan** covers the largest area in Pakistan, with a total area of **345,464 square kilometers**.

# %% [markdown]
# **Question 7.** Which province has the smallest area?

# %%
df.groupby('PROVINCE')['AREA (sq.km)'].sum().sort_values(ascending=True)
# Out:
# PROVINCE
# KPK/FATA        24529.0
# KPK             74957.1
# SINDH          140136.0
# PUNJAB         202693.0
# BALOCHISTAN    345464.0
# Name: AREA (sq.km), dtype: float64

# %% [markdown]
# *Answer:* **KPK/FATA** has the smallest area in Pakistan, with a total area of **24,529 square kilometers**.

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Question 8.** What is the total population of Pakistan (2017) (including both rural and urban areas)?

# %% [markdown]
# creating a new column for total population

# %%
# creating a new column for total population
df['TOTAL POPULATION'] = df['ALL SEXES (RURAL)'] + df['ALL SEXES (URBAN)']

df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
print("Answer: Total Population of Pakistan (2017): ", df['TOTAL POPULATION'].sum())
# Out:
# Answer: Total Population of Pakistan (2017):  204410733

# %% [markdown]
# **Question: 9.** What is the average population of each division?

# %%
# first let's find total populaion by each division
print("Total Population by Division:")
total_pop_division = df.groupby('DIVISION')['TOTAL POPULATION'].sum().sort_values(ascending=False)

total_pop_division
# Out:
# Total Population by Division:
# DIVISION
# LAHORE DIVISION                 19389856
# GUJRANWALA DIVISION             16120861
# Karachi Division                16024894
# FAISALABAD DIVISION             14185231
# MULTAN DIVISION                 12268173
# BAHAWALPUR DIVISION             11452594
# D.G.KHAN DIVISION               10426847
# RAWALPINDI DIVISION             10006624
# MALAKAND DIVISION                9321400
# Hyderabad Division               8780856
# PESHAWAR DIVISION                8193690
# SARGODHA DIVISION                7826342
# SAHIWAL DIVISION                 7378065
# Larkana Division                 6190926
# Sukkur Division                  5542270
# HAZARA DIVISION                  5323155
# Shaheed Benazirabad Division     5275426
# Quetta Division                  5097730
# Mirpurkhas Division              4224945
# MARDAN DIVISION                  3998876
# KOHAT DIVISION                   2976107
# DERA ISMAIL KHAN DIVISION        2759435
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=total_pop_division.values, y=total_pop_division.index, palette='mako')
plt.xlabel('Total Population')
plt.ylabel('Division')
plt.title('Total Population by Each Division')
plt.tight_layout()
plt.show()

# %% [markdown]
# Mean/avg population of each Division

# %%
# now let's find the mean/avg population of each Division
print(" Answer: Average population of each Division:")
avg_pop_division = df.groupby('DIVISION')['TOTAL POPULATION'].mean().sort_values(ascending=False)

avg_pop_division
# Out:
#  Answer: Average population of each Division:
# DIVISION
# LAHORE DIVISION                 1.140580e+06
# SAHIWAL DIVISION                1.054009e+06
# MULTAN DIVISION                 8.762981e+05
# FAISALABAD DIVISION             8.344254e+05
# GUJRANWALA DIVISION             8.060431e+05
# BAHAWALPUR DIVISION             7.635063e+05
# D.G.KHAN DIVISION               7.447748e+05
# MARDAN DIVISION                 5.712680e+05
# Karachi Division                5.341631e+05
# SARGODHA DIVISION               4.603731e+05
# PESHAWAR DIVISION               4.552050e+05
# RAWALPINDI DIVISION             4.548465e+05
# Badin Division                  3.609916e+05
# HAZARA DIVISION                 3.548770e+05
# Shaheed Benazirabad Division    3.516951e+05
# Sukkur Division                 3.079039e+05
# Larkana Division                2.948060e+05
# Hyderabad Division              2.926952e+05
# MALAKAND DIVISION               2.824667e+05
# Mirpurkhas Division             2.347192e+05
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_pop_division.values, y=avg_pop_division.index, palette='viridis')
plt.xlabel('Average Population')
plt.ylabel('Division')
plt.title('Average Population of Each Division')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Question 10.** Which province division has the largest population?

# %%
df.groupby('DIVISION')['TOTAL POPULATION'].sum()
# Out:
# DIVISION
# BAHAWALPUR DIVISION             11452594
# BANNU DIVISION                   2652867
# Badin Division                   1804958
# D.G.KHAN DIVISION               10426847
# DERA ISMAIL KHAN DIVISION        2759435
# FAISALABAD DIVISION             14185231
# GUJRANWALA DIVISION             16120861
# HAZARA DIVISION                  5323155
# Hyderabad Division               8780856
# KOHAT DIVISION                   2976107
# Kalat Division                   1476630
# Karachi Division                16024894
# LAHORE DIVISION                 19389856
# Larkana Division                 6190926
# MALAKAND DIVISION                9321400
# MARDAN DIVISION                  3998876
# MULTAN DIVISION                 12268173
# Makran Division                  2508969
# Mirpurkhas Division              4224945
# Naseerabad Division              1661077
# PESHAWAR DIVISION                8193690
# Quetta Division                  5097730
# RAWALPINDI DIVISION             10006624
# ...

# %%
# Finding division with the largest total population
total_pop_division = df.groupby('DIVISION')['TOTAL POPULATION'].sum().sort_values(ascending=False)
largest_division = total_pop_division[0:1]

largest_division
# Out:
# DIVISION
# LAHORE DIVISION    19389856
# Name: TOTAL POPULATION, dtype: int64

# %% [markdown]
# As we can see the lahore division has the largest population now let's find out in which province lahore division lies

# %%
# finding the province for LAHORE DIVISION
df[df['DIVISION'] == 'LAHORE DIVISION']['PROVINCE'].values[1]
# Out:
# 'PUNJAB'

# %% [markdown]
# ***Answer:** Punjab Divison has the largest population (i.e Lahore Division with 19389856 peoples)*

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Quesion 11.** What is the total population of each province?

# %%
# population of each province
province_pop = df.groupby('PROVINCE')['TOTAL POPULATION'].sum().sort_values(ascending=False)

province_pop
# Out:
# PROVINCE
# PUNJAB         109054593
# SINDH           47844275
# KPK             30497911
# BALOCHISTAN     12286335
# KPK/FATA         4727619
# Name: TOTAL POPULATION, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(y=province_pop.values, x=province_pop.index, palette='Blues_r')
# Out:
# <Axes: xlabel='PROVINCE'>

# %% [markdown]
# ***Answer:** Total Population of each Province:*
#
# 1. *PUNJAB* : 109054593
# 2. *SINDH* : 47844275
# 3. *KPK* : 30497911
# 4. *BALOCHISTAN* : 12286335
# 5. *KPK/FATA* : 4727619

# %% [markdown]
# **Question 12.** What is the gender distribution (male/female) in each province?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# Grouping by province and sum relevant gender columns
gender_distribution = df.groupby("PROVINCE")[
    ["MALE (RURAL)", "MALE (URBAN)", "FEMALE (RURAL)", "FEMALE (URBAN)"]
].sum()

gender_distribution
# Out:
#              MALE (RURAL)  MALE (URBAN)  FEMALE (RURAL)  FEMALE (URBAN)
# PROVINCE
# BALOCHISTAN       4658709       1797980         4220436         1608430
# KPK              12524211       2897645        12367532         2706563
# KPK/FATA          2344159         73438         2243307           66406
# PUNJAB           34695963      20743951        33961383        19640941
# SINDH            11922521      12948294        11086973        11880533

# %%
# creating new columns for Total Male and Female
gender_distribution["TOTAL MALE"] = gender_distribution["MALE (RURAL)"] + gender_distribution["MALE (URBAN)"]
gender_distribution["TOTAL FEMALE"] = gender_distribution["FEMALE (RURAL)"] + gender_distribution["FEMALE (URBAN)"]

gender_distribution
# Out:
#              MALE (RURAL)  MALE (URBAN)  FEMALE (RURAL)  FEMALE (URBAN)  \
# PROVINCE
# BALOCHISTAN       4658709       1797980         4220436         1608430
# KPK              12524211       2897645        12367532         2706563
# KPK/FATA          2344159         73438         2243307           66406
# PUNJAB           34695963      20743951        33961383        19640941
# SINDH            11922521      12948294        11086973        11880533
#
#              TOTAL MALE  TOTAL FEMALE
# PROVINCE
# BALOCHISTAN     6456689       5828866
# KPK            15421856      15074095
# KPK/FATA        2417597       2309713
# PUNJAB         55439914      53602324
# SINDH          24870815      22967506

# %%
print("Answer: Gender Distribution (male/female) in each province:")
gender_distribution_final = gender_distribution[["TOTAL MALE", "TOTAL FEMALE"]]
gender_distribution_final
# Out:
# Answer: Gender Distribution (male/female) in each province:
#              TOTAL MALE  TOTAL FEMALE
# PROVINCE
# BALOCHISTAN     6456689       5828866
# KPK            15421856      15074095
# KPK/FATA        2417597       2309713
# PUNJAB         55439914      53602324
# SINDH          24870815      22967506

# %% [markdown]
# male-to-female ratio

# %%
# Calculating male-to-female ratio for each province
gender_distribution_final['TOTAL MALE'] / gender_distribution_final['TOTAL FEMALE']
gender_distribution_final
# Out:
#              TOTAL MALE  TOTAL FEMALE  MALE/FEMALE RATIO
# PROVINCE
# BALOCHISTAN     6456689       5828866           1.107709
# KPK            15421856      15074095           1.023070
# KPK/FATA        2417597       2309713           1.046709
# PUNJAB         55439914      53602324           1.034282
# SINDH          24870815      22967506           1.082870

# %%
gender_distribution_final.plot(kind='bar', figsize=(10, 6), color=['blue', 'orange'])
plt.title('Gender Distribution in Each Province (2017 Census)')
plt.xlabel('Province')
plt.ylabel('Population')
plt.tight_layout()
plt.show()

# %% [markdown]
# Total Males and Females in Pakistan:

# %%
gender_distribution_final.sum()
# Out:
# TOTAL MALE      104606871
# TOTAL FEMALE     99782504
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Pie chart for overall gender distribution in Pakistan
total_male = gender_distribution_final.sum()[0]
total_female = gender_distribution_final.sum()[1]

plt.figure(figsize=(6, 6))
plt.pie([total_male, total_female],
        labels=['Male', 'Female'],
        autopct='%1.1f%%',
        colors=['green', 'orange'],
        startangle=90,
        explode=(0.05, 0.05))
plt.title('Overall Gender Distribution in Pakistan')
plt.show()

# %% [markdown]
# **Question 13.** In which province is the rural population of all genders the highest?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# Rural population by provience

# %%
# total rural population by provience
rural_population_province = df.groupby('PROVINCE')['ALL SEXES (RURAL)'].sum().sort_values(ascending=False)
rural_population_province
# Out:
# PROVINCE
# PUNJAB         68662922
# KPK            24892840
# SINDH          23011641
# BALOCHISTAN     8879634
# KPK/FATA        4587753
# Name: ALL SEXES (RURAL), dtype: int64

# %%
rural_population_province.plot(kind='bar', color='green', figsize=(10, 6))
plt.title('Rural Population by Province')
plt.xlabel('Province')
plt.ylabel('Rural Population')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Answer:** In PUNJAB the rural population of all Gender is high which is 68657346*

# %% [markdown]
# **Question 14.** What is the urban vs. rural population in each province?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# urban vs rural population

# %%
# grouping province for all sexes urban and rural population
urban_rural = df.groupby('PROVINCE')[['ALL SEXES (URBAN)', 'ALL SEXES (RURAL)']].sum()

urban_rural
# Out:
#              ALL SEXES (URBAN)  ALL SEXES (RURAL)
# PROVINCE
# BALOCHISTAN            3406701            8879634
# KPK                    5605071           24892840
# KPK/FATA                139866            4587753
# PUNJAB                40391671           68662922
# SINDH                 24832634           23011641

# %%
# Bar plot Urban vs Rural population by province
urban_rural.plot(kind='bar', figsize=(10, 6))
plt.title('Urban vs Rural Population by Province')
plt.xlabel('Province')
plt.ylabel('Population')
plt.tight_layout()
plt.show()

# %%
print("Answer: Urban vs. Rural population in each province:")
urban_rural
# Out:
# Answer: Urban vs. Rural population in each province:
#              ALL SEXES (URBAN)  ALL SEXES (RURAL)
# PROVINCE
# BALOCHISTAN            3406701            8879634
# KPK                    5605071           24892840
# KPK/FATA                139866            4587753
# PUNJAB                40391671           68662922
# SINDH                 24832634           23011641

# %% [markdown]
# **Question 15.** What is the overall sex ratio in each province?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# grouping by province and summing up the population by gender columns 
sex_ratio = df.groupby('PROVINCE')[['MALE (RURAL)', 'MALE (URBAN)', 'FEMALE (RURAL)', 'FEMALE (URBAN)']].sum()
sex_ratio
# Out:
#              MALE (RURAL)  MALE (URBAN)  FEMALE (RURAL)  FEMALE (URBAN)
# PROVINCE
# BALOCHISTAN       4658709       1797980         4220436         1608430
# KPK              12524211       2897645        12367532         2706563
# KPK/FATA          2344159         73438         2243307           66406
# PUNJAB           34695963      20743951        33961383        19640941
# SINDH            11922521      12948294        11086973        11880533

# %%
# summing up the rural and urban population for both Male and Female
sex_ratio['TOTAL MALE'] = sex_ratio['MALE (RURAL)'] + sex_ratio['MALE (URBAN)']
sex_ratio['TOTAL FEMALE'] = sex_ratio['FEMALE (RURAL)'] + sex_ratio['FEMALE (URBAN)']

# Calculating sex ratio: females per 1000 males
sex_ratio['SEX RATIO'] = (sex_ratio['TOTAL FEMALE'] / sex_ratio['TOTAL MALE']) * 1000


sex_ratio[['TOTAL MALE', 'TOTAL FEMALE', 'SEX RATIO']]
# Out:
#              TOTAL MALE  TOTAL FEMALE   SEX RATIO
# PROVINCE
# BALOCHISTAN     6456689       5828866  902.763940
# KPK            15421856      15074095  977.450120
# KPK/FATA        2417597       2309713  955.375524
# PUNJAB         55439914      53602324  966.854386
# SINDH          24870815      22967506  923.472190

# %%
sex_ratio['SEX RATIO'].plot(kind='bar', color='purple', figsize=(8, 5))
plt.title('Sex Ratio (Females per 1000 males) in Each Province')
plt.xlabel('Province')
plt.ylabel('Sex Ratio')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Answer:** The overall sex ratio in each (Female per 1000 males) province is as follows:*
# 1. **PUNJAB**: 966.85
# 2. **KPK**: 977.45
# 3. **KPK/FATA**: 955.38
# 4. **BALOCHISTAN**: 902.76
# 5. **SINDH**: 923.47

# %% [markdown]
# **Question 16.** How does the sex ratio differ in urban and rural areas?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# sex ratio (females per 1000 males) in urban and rural areas for each province

# %%
# Grouping by province and sum gender columns
sex_ratio_urban_rural = df.groupby('PROVINCE')[['MALE (URBAN)', 'FEMALE (URBAN)', 'MALE (RURAL)', 'FEMALE (RURAL)']].sum()

# Calculating sex ratio for urban and rural areas
sex_ratio_urban_rural['SEX RATIO URBAN'] = (sex_ratio_urban_rural['FEMALE (URBAN)'] / sex_ratio_urban_rural['MALE (URBAN)']) * 1000
sex_ratio_urban_rural['SEX RATIO RURAL'] = (sex_ratio_urban_rural['FEMALE (RURAL)'] / sex_ratio_urban_rural['MALE (RURAL)']) * 1000

# %% [markdown]
# Sex ratio in urban and rural areas for each province

# %%
sex_ratio_urban_rural[['SEX RATIO URBAN', 'SEX RATIO RURAL']]
# Out:
#              SEX RATIO URBAN  SEX RATIO RURAL
# PROVINCE
# BALOCHISTAN       894.576135       905.923937
# KPK               934.056104       987.489911
# KPK/FATA          904.245758       956.977321
# PUNJAB            946.827391       978.828084
# SINDH             917.536550       929.918513

# %%
sex_ratio_urban_rural[['SEX RATIO URBAN', 'SEX RATIO RURAL']].plot(kind='bar', figsize=(10, 6))
plt.title('Sex Ratio (Females per 1000 Males) in Urban vs Rural Areas by Province')
plt.xlabel('Province')
plt.ylabel('Sex Ratio')
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Answer:** The sex ratio (females per 1000 males) is higher in rural areas compared to urban areas for all provinces. For example, in Punjab, the rural sex ratio is 978.83 while the urban is 946.83; in KPK, rural is 987.49 and urban is 934.06.*

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %% [markdown]
# **Question 17.** What is the average household size in each province (both by Rural and Urban)?

# %% [markdown]
# average household size of Rural area by province

# %%
# average household size rural area
avg_house_size_rural = df.groupby('PROVINCE')['AVG HOUSEHOLD SIZE (RURAL)'].mean()
avg_house_size_rural
# Out:
# PROVINCE
# BALOCHISTAN    6.597099
# KPK            8.089437
# KPK/FATA       8.683478
# PUNJAB         6.146783
# SINDH          4.359781
# Name: AVG HOUSEHOLD SIZE (RURAL), dtype: float64

# %% [markdown]
# average household size of Urban area by province

# %%
# average household size urban area
avg_house_size_urban = df.groupby('PROVINCE')['AVG HOUSEHOLD SIZE (URBAN)'].mean()
avg_house_size_urban
# Out:
# PROVINCE
# BALOCHISTAN    2.916336
# KPK            4.297887
# KPK/FATA       0.861739
# PUNJAB         6.127343
# SINDH          5.281314
# Name: AVG HOUSEHOLD SIZE (URBAN), dtype: float64

# %% [markdown]
# ***Answer:** The average household size in each province (by Rural and Urban areas) is:*
#
# - **PUNJAB:** Rural 6.15, Urban 6.12
# - **SINDH:** Rural 4.36, Urban 5.28
# - **KPK:** Rural 8.09, Urban 4.30
# - **BALOCHISTAN:** Rural 6.60, Urban 2.92
# - **KPK/FATA:** Rural 8.68, Urban 0.86

# %% [markdown]
# **Question 18.** How does the average household size differ between rural and urban areas?

# %% [markdown]
# difference in average household size between rural and urban areas

# %%
print("Answer: Difference in Average Household Size (Rural - Urban)")
avg_house_size_diff = avg_house_size_rural - avg_house_size_urban
avg_house_size_diff
# Out:
# Answer: Difference in Average Household Size (Rural - Urban)
# PROVINCE
# BALOCHISTAN    3.680763
# KPK            3.791549
# KPK/FATA       7.821739
# PUNJAB         0.019441
# SINDH         -0.921533
# dtype: float64

# %% [markdown]
# **Question 19.** What was the population of each province in the 1998 census?

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# creating a new column for total population 1998
df['POPULATION 1998 (TOTAL)'] = df['POPULATION 1998 (URBAN)'] + df['POPULATION 1998 (RURAL)']

df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# total pop in 1998 by province
total_pop_1998 = df.groupby('PROVINCE')['POPULATION 1998 (TOTAL)'].sum().sort_values(ascending=False)

print("Answer: Total Population in 1998 by Province:")
total_pop_1998
# Out:
# Answer: Total Population in 1998 by Province:
# PROVINCE
# PUNJAB         73004786
# SINDH          30429937
# KPK            17776387
# BALOCHISTAN     6539503
# KPK/FATA        2967699
# Name: POPULATION 1998 (TOTAL), dtype: int64

# %%
# plotting total population in 1998 by province
plt.figure(figsize=(10, 6))
plt.bar(total_pop_1998.index, total_pop_1998.values, color='skyblue')
plt.title('Total Population in 1998 by Province')
plt.xlabel('Province')
plt.ylabel('Population')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Question 20.** What is the growth rate of the population in each province from 1998 to 2017?

# %% [markdown]
# pop growth rate from 1998 to 2017 by province

# %%
province_pop_2017 = df.groupby('PROVINCE')['TOTAL POPULATION'].sum()
province_pop_1998 = df.groupby('PROVINCE')['POPULATION 1998 (TOTAL)'].sum()
pop_growth_rate_province = ((province_pop_2017 - province_pop_1998) / province_pop_1998) * 100

print("Answer: Population Growth Rate from 1998 to 2017 by Province:")
pop_growth_rate_province
# Out:
# Answer: Population Growth Rate from 1998 to 2017 by Province:
# PROVINCE
# BALOCHISTAN    87.878727
# KPK            71.564171
# KPK/FATA       59.302510
# PUNJAB         49.380060
# SINDH          57.227651
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.bar(pop_growth_rate_province.index, pop_growth_rate_province.values, color='lightgreen')
plt.title('Population Growth Rate from 1998 to 2017 by Province')
plt.xlabel('Province')
plt.ylabel('Growth Rate (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Summary**

# %% [markdown]
# ### Summary of the Analysis
#
# In this analysis I take a look at Pakistan's population and administrative setup using the 2017 census data. Here are the key findings from the analysis:
#
# #### Administrative Units
# - **Provinces:** There are five main provinces/regions: Punjab, Sindh, KPK, Balochistan, and KPK/FATA.
# - **Divisions:** Punjab has the most divisions (9), Sindh and KPK have 7 each, Balochistan has 5, and KPK/FATA also has 5.
# - **Districts:** Punjab has 36 districts, Balochistan 31, Sindh 29, KPK 23, and KPK/FATA 12.
# - **Sub-divisions:** Punjab leads with 143, Sindh has 137, Balochistan 131, KPK 71, and KPK/FATA 46.
#
# #### Population Insights
# - **Total Population (2017):**
#     - Punjab: 109,054,593
#     - Sindh: 47,844,275
#     - KPK: 30,497,911
#     - Balochistan: 12,286,335
#     - KPK/FATA: 4,727,619
# - **Largest Division:** Lahore Division in Punjab has the biggest population: 19,389,856.
# - **Urban vs Rural:** Punjab and Sindh have a lot of people living in cities, but in most provinces, more people live in villages except Sindh, where it’s almost equal.
# - **Rural Population:** Punjab has the highest rural population (68,662,922), then KPK (24,892,840), and Sindh (23,011,641).
#
# #### Gender Distribution & Sex Ratio
# - **Overall:** There are a bit more males than females in every province. For example, in Balochistan, the male/female ratio is about 1.11, and in KPK, it’s about 1.02.
# - **Sex Ratio (Females per 1000 Males):** Highest in KPK (977), lowest in Balochistan (903).
# - **Urban vs Rural:** Usually, the sex ratio is higher in rural areas than in cities.
#
# #### Household Size
# - **Average Household Size:** People in villages usually live in bigger families. KPK and KPK/FATA have the biggest rural household sizes (8.09 and 8.68).
#
# #### Area
# - **Largest Province by Area:** Balochistan is the biggest (345,464 sq.km).
# - **Smallest by Area:** KPK/FATA is the smallest (24,529 sq.km).
#
# #### Population Growth
# - **Growth Rate (1998-2017):**
#     - Balochistan: 87.88%
#     - KPK: 71.56%
#     - KPK/FATA: 59.30%
#     - Sindh: 57.23%
#     - Punjab: 49.38%
#
# #### Key Takeaways
# - Punjab has the most people and the most districts/divisions.
# - Balochistan is huge in area but not many people live there compared to its size.
# - Sindh is the most urbanized (lots of people live in cities).
# - There are more males than females, especially in Balochistan.
# - Population is growing really fast in Balochistan and KPK.

# %% [markdown]
# ***Thank you for reviewing my analysis on Pakistan Population 2017. If you found this notebook helpful or insightful, please consider giving it an upvote! Your feedback and support are appreciated.***
